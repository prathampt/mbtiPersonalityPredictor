# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /home/pratham/.mySpace/lib/python3.11/site-packages (24.2)
# Collecting pip
#   Downloading pip-24.3.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-24.3.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 296.1 kB/s eta 0:00:001m309.0 kB/s eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.2
#     Uninstalling pip-24.2:
#       Successfully uninstalled pip-24.2
# Successfully installed pip-24.3.1

# %%
# !pip install tensorflow opencv-python matplotlib dlib
# Out:
# Requirement already satisfied: tensorflow in /home/pratham/.mySpace/lib/python3.11/site-packages (2.17.0)
# Requirement already satisfied: opencv-python in /home/pratham/.mySpace/lib/python3.11/site-packages (4.10.0.84)
# Requirement already satisfied: matplotlib in /home/pratham/.mySpace/lib/python3.11/site-packages (3.9.1)
# Collecting dlib
#   Using cached dlib-19.24.6.tar.gz (3.4 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py>=1.0.0 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (66.1.1)
# Requirement already satisfied: six>=1.12.0 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (1.66.2)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/pratham/.mySpace/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/pratham/.mySpace/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pratham/.mySpace/lib/python3.11/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/pratham/.mySpace/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in /home/pratham/.mySpace/lib/python3.11/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/pratham/.mySpace/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/pratham/.mySpace/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/pratham/.mySpace/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /home/pratham/.mySpace/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (13.9.2)
# Requirement already satisfied: namex in /home/pratham/.mySpace/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /home/pratham/.mySpace/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/pratham/.mySpace/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/pratham/.mySpace/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/pratham/.mySpace/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pratham/.mySpace/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/pratham/.mySpace/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/pratham/.mySpace/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/pratham/.mySpace/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/pratham/.mySpace/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/pratham/.mySpace/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Building wheels for collected packages: dlib
#   Building wheel for dlib (setup.py) ... done
#   Created wheel for dlib: filename=dlib-19.24.6-cp311-cp311-linux_x86_64.whl size=3599315 sha256=01094c59eacfb9d3751961d826a38472e7dce00c45f693b16ed77aa447e69ae8
#   Stored in directory: /home/pratham/.cache/pip/wheels/fe/c7/1f/c778b9f7cc6d8d0da4f6697f619f9eb5a49d54d2a2c8267f3c
# Successfully built dlib
# Installing collected packages: dlib
# Successfully installed dlib-19.24.6

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
import os
import cv2
import dlib
import imghdr
import numpy as np
import matplotlib.pyplot as plt

# %%
# gpus = tf.config.experimental.list_physical_devices("GPU")
# for gpu in gpus:
#     tf.config.experimental.set_memory_growth(gpu, True)

# %%
data_dir = "./data/finalData/handPicked/MBTI_Images/"
cropped_data_dir = "./data/finalData/handPicked/cropped_data/"

# %%
# need to mogrify all the images in the png format... command for same in each directory is "mogrify *.png"

# %%
image_exts = ['jpeg','jpg', 'bmp', 'png']

# %%
folder_image_counts = {}

for image_class in os.listdir(cropped_data_dir):
    valid_image_count = 0
    for image in os.listdir(os.path.join(cropped_data_dir, image_class)):
        image_path = os.path.join(cropped_data_dir, image_class, image)
        try:
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
            else:
                valid_image_count += 1
        except Exception as e:
            print('Issue with image {}'.format(image_path))
            os.remove(image_path)      
            
    folder_image_counts[image_class] = valid_image_count 

for image_class, count in folder_image_counts.items():
    print(f'Folder "{image_class}" contains {count} valid images')
# Out:
# Folder "ESTJ" contains 52 valid images
# Folder "INFP" contains 111 valid images
# Folder "ISTP" contains 77 valid images
# Folder "INTJ" contains 82 valid images
# Folder "ISFP" contains 91 valid images
# Folder "ENTJ" contains 201 valid images
# Folder "ESTP" contains 196 valid images
# Folder "ISFJ" contains 107 valid images
# Folder "ENFJ" contains 72 valid images
# Folder "ESFP" contains 51 valid images
# Folder "ENTP" contains 197 valid images
# Folder "ESFJ" contains 99 valid images
# Folder "INTP" contains 82 valid images
# Folder "ENFP" contains 55 valid images
# Folder "ISTJ" contains 79 valid images
# Folder "INFJ" contains 202 valid images

# %% [markdown]
# # Loading data

# %% [markdown]
# ## Crop and save images...

# %%
# # Initialize face detector and landmark predictor
# face_detector = dlib.get_frontal_face_detector()
# landmark_predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')

# # Define image extensions
# image_exts = ['rgb', 'gif', 'pbm', 'pgm', 'ppm', 'tiff', 'rast', 'xbm', 'jpeg', 'jpg', 'bmp', 'png', 'webp', 'exr']

# # Data directory
# # data_dir = 'data'  # Replace with your data directory

# # Cropped data directory
# cropped_data_dir = './data/finalData/handPicked/cropped_data' # Replace with your cropped data directory

# def crop_and_save_face(image_path, output_dir):
#     try:
#         img = cv2.imread(image_path)
#         if img is None:
#             raise ValueError("Could not read image")

#         gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#         faces = face_detector(gray, 1)

#         for i, face in enumerate(faces):  # Handle multiple faces in an image
#             landmarks = landmark_predictor(gray, face)
#             x1 = max(0, landmarks.part(0).x)
#             y1 = max(0, landmarks.part(17).y)  # Top of forehead
#             x2 = min(img.shape[1], landmarks.part(16).x)
#             y2 = min(img.shape[0], landmarks.part(8).y)  # Bottom of chin

#             if x1 >= x2 or y1 >= y2:
#                 print(f"Invalid face coordinates for {image_path}. Skipping face {i+1}.")
#                 continue  # Skip this face

#             face_image = img[y1:y2, x1:x2]
#             try:
#                 face_image = cv2.resize(face_image, (200, 200))
#                 output_path = os.path.join(output_dir, f"{os.path.splitext(os.path.basename(image_path))[0]}_face{i+1}.jpg")
#                 cv2.imwrite(output_path, face_image)
#             except Exception as e:
#                 print(f"Error processing face {i+1} in {image_path}: {e}")

#         if not faces:
#             print(f"No face detected in {image_path}. Resizing and saving original.")
#             resized_img = cv2.resize(img, (200, 200))
#             output_path = os.path.join(output_dir, os.path.basename(image_path))
#             cv2.imwrite(output_path, resized_img)

#     except Exception as e:
#         print(f"Error processing {image_path}: {e}")


# # Create the cropped data directory if it doesn't exist
# os.makedirs(cropped_data_dir, exist_ok=True)

# for image_class in os.listdir(data_dir):
#     class_dir = os.path.join(data_dir, image_class)
#     if not os.path.isdir(class_dir):
#         continue  # Skip if not a directory

#     cropped_class_dir = os.path.join(cropped_data_dir, image_class)
#     os.makedirs(cropped_class_dir, exist_ok=True) # Create class directory in cropped folder

#     for image in os.listdir(class_dir):
#         image_path = os.path.join(class_dir, image)
#         tip = imghdr.what(image_path)
#         if tip in image_exts:
#             crop_and_save_face(image_path, cropped_class_dir)
#         else:
#             print(f'Invalid image format: {image_path}')

# %%
# tf.keras.utils.image_dataset_from_directory??

# %%
# Define MBTI personality types mapping to 4 binary labels (E-I, S-N, T-F, J-P)
categoryMap = {
    'ENFJ': [1, 1, 0, 1],  # E-I, S-N, T-F, J-P
    'ENTJ': [1, 1, 1, 1],
    'ESFJ': [1, 0, 0, 1],
    'ESTJ': [1, 0, 1, 1],
    'INFJ': [0, 1, 0, 1],
    'INTJ': [0, 1, 1, 1],
    'ISFJ': [0, 0, 0, 1],
    'ISTJ': [0, 0, 1, 1],
    'ENFP': [1, 1, 0, 0],
    'ENTP': [1, 1, 1, 0],
    'ESFP': [1, 0, 0, 0],
    'ESTP': [1, 0, 1, 0],
    'INFP': [0, 1, 0, 0],
    'INTP': [0, 1, 1, 0],
    'ISFP': [0, 0, 0, 0],
    'ISTP': [0, 0, 1, 0]
}

def map_class_to_mbti_label(class_ids):
    class_names = ['ENFJ', 'ENFP', 'ENTJ', 'ENTP', 'ESFJ', 'ESFP', 'ESTJ', 'ESTP', 
                   'INFJ', 'INFP', 'INTJ', 'INTP', 'ISFJ', 'ISFP', 'ISTJ', 'ISTP']

    class_ids = np.asarray(class_ids)
    
    mbti_labels = np.array([categoryMap[class_names[class_id]] for class_id in class_ids], dtype=np.int32)
    mbti_labels = mbti_labels.reshape(-1, 4)
    
    return mbti_labels

def process_image(image, label):
    image = image / 255.0
    # Convert label to MBTI binary labels
    label = tf.py_function(func=map_class_to_mbti_label, inp=[label], Tout=tf.int32)
    label.set_shape([None, 4])  # Batch size, 4 for E-I, S-N, T-F, J-P
    
    return image, label

# %%
data = tf.keras.utils.image_dataset_from_directory(
    cropped_data_dir,  
    image_size=(200, 200), 
    batch_size=32, 
    shuffle=True,
    class_names=['ENFJ', 'ENFP', 'ENTJ', 'ENTP', 'ESFJ', 'ESFP', 'ESTJ', 'ESTP', 
                 'INFJ', 'INFP', 'INTJ', 'INTP', 'ISFJ', 'ISFP', 'ISTJ', 'ISTP']
)
# Out:
# Found 1754 files belonging to 16 classes.

# %%
data_iterator = data.as_numpy_iterator() # Allow us to access our data pypeline

# %%
batch = data_iterator.next() # actually accessing the data pipeline

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Scale

# %%
# We are over-riding our data here, we can give it to some other variable also
# data = data.map(lambda x,y: (x/255, y)) # Adding a map function to the pipeline, to transform the data set from 0 to 1, rather than from 0 to 255...

# %%
data = data.map(process_image)

# %%
data
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=(None, 200, 200, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.int32, name=None))>

# %% [markdown]
# ### Here we need to map our different preprocessed function, or first run the pre-processing function, and then use that data. We should try to integrate the preprocessing function (ie. just cropping the faces) to the pypeline, this might help.

# %%
scaled_iterator = data.as_numpy_iterator()

# %%
batch = scaled_iterator.next()

# %%
print(batch[0].min())
print(batch[0].max())
# Out:
# 0.0
# 1.0

# %%
print(len(batch[0]))
# Out:
# 32

# %% [markdown]
# ## Split Data

# %%
len(data)
# Out:
# 55

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1) + 1
print(train_size, val_size, test_size)
# Out:
# 38 11 6

# %%
train_size + val_size + test_size == len(data)
# Out:
# True

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# # Deep Model

# %% [markdown]
# ## Model Building

# %%
train
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 200, 200, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.int32, name=None))>

# %%
from tensorflow import keras
from keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization, concatenate, GlobalAveragePooling2D
from keras.models import Model
from keras.regularizers import l2  # For L2 regularization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# model = Sequential()
# Here, we are using the sequential model. We will need to use the functional model in the keras library
# to make multiple input and multiple output. (Actually we only need single input and multiple output).

# %%
def create_model():
    inputs = Input(shape=(200, 200, 3))

    # Convolutional Blocks with Batch Normalization and LeakyReLU
    x = Conv2D(32, (3, 3), strides=1, padding='same')(inputs)  # 'same' padding
    x = BatchNormalization()(x)
    x = keras.layers.LeakyReLU(alpha=0.1)(x)
    x = MaxPooling2D()(x)
    x = Dropout(0.25)(x)

    x = Conv2D(64, (3, 3), strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = keras.layers.LeakyReLU(alpha=0.1)(x)
    x = MaxPooling2D()(x)
    x = Dropout(0.25)(x)

    x = Conv2D(128, (3, 3), strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = keras.layers.LeakyReLU(alpha=0.1)(x)
    x = MaxPooling2D()(x)
    x = Dropout(0.25)(x)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)


    # Fully Connected Layers with L2 Regularization
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(x)  # L2 regularization
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)


    # Output Branches (similar structure for all)
    def create_branch(name):
        branch = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
        branch = BatchNormalization()(branch)
        branch = Dropout(0.4)(branch)
        return Dense(1, activation='sigmoid', name=name)(branch)

    output_ei = create_branch('output_ei')
    output_sn = create_branch('output_sn')
    output_tf = create_branch('output_tf')
    output_jp = create_branch('output_jp')


    outputs = concatenate([output_ei, output_sn, output_tf, output_jp])

    model = Model(inputs=inputs, outputs=outputs)
    return model


# Model Compilation and Training with Callbacks
model = create_model()
optimizer = Adam(learning_rate=0.001)  # Initial learning rate
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 200, 200,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 200, 200,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 200, 200,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 200, 200,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 100, 100,  │          0 │ leaky_re_lu[0][0] │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 100, 100,  │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 100, 100,  │     18,496 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100, 100,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 100, 100,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 50, 50,    │          0 │ leaky_re_lu_1[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 50, 50,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 50, 50,    │     73,856 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 50,    │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 50, 50,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 25, 25,    │          0 │ leaky_re_lu_2[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 25, 25,    │          0 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ dropout_2[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │     66,048 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │     32,896 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │     32,896 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │     32,896 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │     32,896 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_5[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_ei (Dense)   │ (None, 1)         │        129 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_sn (Dense)   │ (None, 1)         │        129 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_tf (Dense)   │ (None, 1)         │        129 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_jp (Dense)   │ (None, 1)         │        129 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 4)         │          0 │ output_ei[0][0],  │
# │ (Concatenate)       │                   │            │ output_sn[0][0],  │
# │                     │                   │            │ output_tf[0][0],  │
# │                     │                   │            │ output_jp[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 428,740 (1.64 MB)
#  Trainable params: 425,732 (1.62 MB)
#  Non-trainable params: 3,008 (11.75 KB)

# %% [markdown]
# ## Model Training

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=10, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 37s 886ms/step - accuracy: 0.2713 - loss: 2.1591 - val_accuracy: 0.2330 - val_loss: 1.7813
# Epoch 2/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 33s 862ms/step - accuracy: 0.2667 - loss: 1.9543 - val_accuracy: 0.1449 - val_loss: 1.7204
# Epoch 3/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 33s 873ms/step - accuracy: 0.2351 - loss: 1.8900 - val_accuracy: 0.1165 - val_loss: 1.6785
# Epoch 4/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 34s 885ms/step - accuracy: 0.2513 - loss: 1.7886 - val_accuracy: 0.2557 - val_loss: 1.6525
# Epoch 5/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 34s 886ms/step - accuracy: 0.2677 - loss: 1.7028 - val_accuracy: 0.2670 - val_loss: 1.6134
# Epoch 6/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 33s 877ms/step - accuracy: 0.2821 - loss: 1.6880 - val_accuracy: 0.2756 - val_loss: 1.5992
# Epoch 7/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 33s 876ms/step - accuracy: 0.2540 - loss: 1.6367 - val_accuracy: 0.2898 - val_loss: 1.5576
# Epoch 8/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 33s 879ms/step - accuracy: 0.2453 - loss: 1.5800 - val_accuracy: 0.1278 - val_loss: 1.4925
# Epoch 9/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 33s 877ms/step - accuracy: 0.2739 - loss: 1.5348 - val_accuracy: 0.2699 - val_loss: 1.4950
# Epoch 10/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 34s 885ms/step - accuracy: 0.2634 - loss: 1.4970 - val_accuracy: 0.2557 - val_loss: 1.4314

# %% [markdown]
# ## Plot performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # Evaluate

# %%
from tensorflow.keras.metrics import Precision, Recall, Accuracy

# %%
pre = Precision()
re = Recall()
acc = Accuracy()

# %%
for batch in test.as_numpy_iterator():
    X, y = batch
    yhat = model.predict(X)

    # Convert predictions to classes (0 or 1) for each MBTI dimension
    yhat_classes = (yhat > 0.5).astype(int)  # Assuming 0.5 as the threshold

    # Reshape y to match yhat_classes if necessary
    if y.shape[1] == 1: # if y represents a single dimension
        y = np.repeat(y, 4, axis=1) # repeat across 4 dimensions for consistency
    elif y.ndim == 1: # if y is a 1D array
        y = y.reshape(-1, 1) # reshape to a column vector
        y = np.repeat(y, 4, axis=1)

    pre.update_state(y, yhat_classes)
    re.update_state(y, yhat_classes)
    acc.update_state(y, yhat_classes)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 2024-11-02 00:24:23.974559: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
print(f'Precision: {pre.result().numpy()}')
print(f'Recall: {re.result().numpy()}')
print(f'Accuracy: {acc.result().numpy()}')
# Out:
# Precision: 0.5277777910232544
# Recall: 0.4947916567325592
# Accuracy: 0.5107526779174805

# %% [markdown]
# # Test

# %%
imageName = "ENFJ/Aditi_Rao_hydari_angry_face1.jpg"
img = cv2.imread(cropped_data_dir + imageName) # Read some image, and test...
# plt.imshow(img)
# plt.show()

# %%
resize = tf.image.resize(img, (200,200))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %%
yhat
# Out:
# array([[0.34573227, 0.59132886, 0.5523019 , 0.5798808 ]], dtype=float32)

# %%
def predictPersonalityType(yhat):
    personalityType = ""
    
    if yhat[0][0] > 0.5:
        personalityType += "E"
    else:
        personalityType += "I"
    
    if yhat[0][1] > 0.5:
        personalityType += "N"
    else:
        personalityType += "S"
    
    if yhat[0][2] > 0.5:
        personalityType += "T"
    else:
        personalityType += "F"
    
    if yhat[0][3] > 0.5:
        personalityType += "J"
    else:
        personalityType += "P"
    
    print(f"Personality type: {personalityType}")
    return personalityType

predictPersonalityType(yhat)
# Out:
# Personality type: INTJ
# 'INTJ'

# %% [markdown]
# # Save the model

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','imageclassifierCroppedImagesVersion1.keras'))

# %%
new_model = load_model('./models/imageclassifier.keras')

# %%
imageName = "/home/pratham/pratham/temp.jpeg"
img = cv2.imread(imageName) # Read some image, and test...
resize = tf.image.resize(img, (200,200))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
p = new_model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
def predictPersonalityType(yhat):
    personalityType = ""
    
    if yhat[0][0] > 0.5:
        personalityType += "E"
    else:
        personalityType += "I"
    
    if yhat[0][1] > 0.5:
        personalityType += "N"
    else:
        personalityType += "S"
    
    if yhat[0][2] > 0.5:
        personalityType += "T"
    else:
        personalityType += "F"
    
    if yhat[0][3] > 0.5:
        personalityType += "J"
    else:
        personalityType += "P"
    
    print(f"Personality type: {personalityType}")
    return personalityType

predictPersonalityType(p)
# Out:
# Personality Type is ISFP
